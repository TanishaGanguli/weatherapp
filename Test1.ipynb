# %% [markdown]
# <a href="https://colab.research.google.com/github/TanishaGanguli/weatherapp/blob/master/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
pip install lxml

# %%
pip install lxml

# %%
import requests
import bs4

# %%
result=requests.get("https://www.karnatakatourism.org/things-to-do/")

# %%
soup=bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="width=device-width,initial-scale=1,user-scalable=yes" name="viewport"/>
# <script type="application/javascript">var mkdfToursAjaxURL="https://www.karnatakatourism.org/wp-admin/admin-ajax.php"</script>
# <!-- This site is optimized with the Yoast SEO plugin v14.4.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Things To Do in karnataka | Explore Activities | Karnataka Tourism</title>
# <meta content="Things To Do in Karnataka like Adventures, Festivals, Cuisines and Shopping karnataka and many more activities." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>
# ...

# %%
soup.select('.mkdf-tour-title')
# Out:
# [<h4 class="mkdf-tour-title">
#  								Adventure							</h4>, <h4 class="mkdf-tour-title">
#  								Festivals							</h4>, <h4 class="mkdf-tour-title">
#  								The Wild							</h4>, <h4 class="mkdf-tour-title">
#  								Cuisines							</h4>, <h4 class="mkdf-tour-title">
#  								Golf Courses of Karnataka							</h4>, <h4 class="mkdf-tour-title">
#  								Wellness							</h4>, <h4 class="mkdf-tour-title">
#  								Shopping in Karnataka							</h4>, <h4 class="mkdf-tour-title">
#  								Theme Parks / Recreational Tourism							</h4>]

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-2145ef3f-6b31-43f0-8430-87f827b22f39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2145ef3f-6b31-43f0-8430-87f827b22f39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
import io
df=pd.read_xlsx(io.BytesIO(upload['test1.xlsx']))
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7cd2d14e6b43> in <module>()
#       1 import pandas as pd
#       2 import io
# ----> 3 df=pd.read_xlsx(io.BytesIO(upload['test1.xlsx']))
#       4 print(df)
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
